# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhi311509/Rice-Leaf-Detection/blob/main/CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
from skimage import io
import os, json, cv2, random

img_path = "/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight.jpg"
image = cv2.imread(img_path)
cv2_imshow(image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-19294d4aa604> in <module>
#       5 img_path = "/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight.jpg"
#       6 image = cv2.imread(img_path)
# ----> 7 cv2_imshow(image)
#
# /usr/local/lib/python3.8/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
img = cv2.imread('/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight.jpg')
img

# %%
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-d0027ef4e25a> in <module>
# ----> 1 cv2_imshow(img)
#
# /usr/local/lib/python3.8/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
import cv2

from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight.jpg')
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-cd82d2fcbfed> in <module>
#       1 img = cv2.imread('/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight.jpg')
# ----> 2 cv2_imshow(img)
#
# /usr/local/lib/python3.8/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
img_path= ('/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight.JPG')
img = cv2.imread(img_path)
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-353de1b7d47d> in <module>
#       1 img_path= ('/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight.JPG')
#       2 img = cv2.imread(img_path)
# ----> 3 cv2_imshow(img)
#
# /usr/local/lib/python3.8/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
import cv2
import os

def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        if img is not None:
            images.append(img)
    return images

# %%
load_images_from_folder("/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight")
# Out:
# [array([[[223, 229, 240],
#          [222, 228, 239],
#          [222, 228, 239],
#          ...,
#          [225, 230, 239],
#          [225, 230, 239],
#          [226, 231, 240]],
#
#         [[222, 228, 239],
#          [222, 228, 239],
#          [222, 228, 239],
#          ...,
#          [225, 230, 239],
#          [226, 231, 240],
#          [225, 230, 239]],
#
#         [[221, 227, 238],
#          [221, 227, 238],
#          [222, 228, 239],
#          ...,
#          [226, 231, 240],
#          [227, 232, 241],
#          [226, 231, 240]],
#
#         ...,
#
#         [[217, 227, 237],
#          [217, 227, 237],
#          [218, 228, 238],
#          ...,
#          [223, 226, 240],
#          [224, 227, 241],
#          [223, 226, 240]],
#
#         [[217, 227, 237],
#          [217, 227, 237],
#          [218, 228, 238],
#          ...,
#          [221, 225, 236],
#          [222, 225, 239],
#          [223, 226, 240]],
#
#         [[219, 228, 238],
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(40):
    ax = fig.add_subplot(4, 10, i + 1, xticks=[], yticks=[])
    ax.imshow(images[i])

# %%
x= c[:]
y= c[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-f5492978ce5c> in <module>
# ----> 1 x= c[:]
#       2 y= c[:]
#
# TypeError: 'AxesImage' object is not subscriptable

# %%
(x_train, y_train), (x_test, y_test) = train_test_split(x, y, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-40fb299c4b8e> in <module>
# ----> 1 (x_train, y_train), (x_test, y_test) = train_test_split(x, y, random_state=1)
#
# ValueError: too many values to unpack (expected 2)

# %%
from sklearn.model_selection import train_test_split
# create dataset
X, y = c()
# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-dbf10f5df3ca> in <module>
#       1 from sklearn.model_selection import train_test_split
#       2 # create dataset
# ----> 3 X, y = c()
#       4 # split into train test sets
#       5 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
#
# TypeError: 'AxesImage' object is not callable

# %%
# split into input and output elements
data = images.values
X, y = data[:, :-1], data[:, -1]
print(X.shape, y.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-5cf27d260a0b> in <module>
#       1 # split into input and output elements
# ----> 2 data = images.values
#       3 X, y = data[:, :-1], data[:, -1]
#       4 print(X.shape, y.shape)
#
# AttributeError: 'list' object has no attribute 'values'

# %%
# !pip install split-folders

import splitfolders
splitfolders.ratio('Bacterial leaf blight', output="output", seed=1337, ratio=(.8, 0.0,0.2))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-c557dad683e1> in <module>
#       2
#       3 import splitfolders
# ----> 4 splitfolders.ratio('Bacterial leaf blight', output="output", seed=1337, ratio=(.8, 0.0,0.2))
#
# /usr/local/lib/python3.8/dist-packages/splitfolders/split.py in ratio(input, output, seed, ratio, group_prefix, move)
#      79         raise ValueError("`ratio` should")
#      80
# ---> 81     check_input_format(input)
#      82
#      83     if use_tqdm:
#
# /usr/local/lib/python3.8/dist-packages/splitfolders/split.py in check_input_format(input)
#      54         if not p_input.is_absolute():
#      55             err_msg += f' Your relative path cannot be found from the current working directory "{Path.cwd()}".'
# ...

# %%
from __future__ import absolute_import, print_function,division, unicode_literals

import os.path
import glob
import shutil

import tensorflow as tf
assert tf.__version__.startswith('2')

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D,Flatten,MaxPooling2D,Dropout,Dense,Activation
from keras import regularizers
import keras

import numpy as np
import matplotlib.pyplot as plt
import pathlib

# %%
import pathlib
data_dir ="/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data"
data_dir = pathlib.Path(data_dir)

CLASS_NAMES = np.array(['Bacterial leaf Blight','Brown spot','Leaf smut'])

print('Class Names: ', CLASS_NAMES)
# Out:
# Class Names:  ['Bacterial leaf Blight' 'Brown spot' 'Leaf smut']

# %%
BATCH_SIZE = 8
IMG_HEIGHT = 224
IMG_WIDTH = 224

# %%
train_path = "/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data"
test_path = "/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data"

# %%
image_train_gen = ImageDataGenerator(rescale=1./255,
                                     zoom_range=0.50,
                                     rotation_range=45,
                                     horizontal_flip=True,
                                     width_shift_range=0.15,
                                     height_shift_range=0.15)

train_data_gen = image_train_gen.flow_from_directory(train_path,
                                                     shuffle=True,
                                                     batch_size=BATCH_SIZE,
                                                     target_size=(IMG_HEIGHT,IMG_WIDTH),
                                                     class_mode='sparse')

img_val_gen = ImageDataGenerator(rescale=1./255)
val_data_gen = img_val_gen.flow_from_directory(test_path,
                                               batch_size=BATCH_SIZE,
                                               target_size=(IMG_HEIGHT,IMG_WIDTH),
                                               class_mode='sparse')
# Out:
# Found 119 images belonging to 3 classes.
# Found 119 images belonging to 3 classes.

# %%
def plotImages(image_arr):
    fig,axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img,ax in zip(image_arr,axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
img_array = [train_data_gen[0][0][0] for i in range(119)]
plotImages(img_array)

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import os

import cv2




from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

from sklearn.metrics import confusion_matrix
import itertools
from sklearn.metrics import classification_report

import shutil

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224
IMAGE_CHANNELS = 3

# %%
os.listdir('/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data')
# Out:
# ['Leaf smut-20200814T055530Z-001',
#  'Brown spot-20200814T055208Z-001',
#  'Bacterial leaf blight-20200814T055237Z-001']

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
leaf_smut_list = \
os.listdir('/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Leaf smut-20200814T055530Z-001/Leaf smut')
brown_spot_list = \
os.listdir('/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Brown spot-20200814T055208Z-001/Brown spot')
bacterial_leaf_blight_list = \
os.listdir('/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight')

print(len(leaf_smut_list))
print(len(brown_spot_list))
print(len(bacterial_leaf_blight_list))
# Out:
# 40
# 40
# 40

# %%
df_leaf_smut = pd.DataFrame(leaf_smut_list, columns=['image'])
df_leaf_smut['target'] = 'leaf_smut'

df_brown_spot = pd.DataFrame(brown_spot_list, columns=['image'])
df_brown_spot['target'] = 'brown_spot'

df_bacterial_leaf_blight = pd.DataFrame(bacterial_leaf_blight_list, columns=['image'])
df_bacterial_leaf_blight['target'] = 'bacterial_leaf_blight'


# Create a val set for each class

# Sample 5 validation images from each class
df_leaf_smut_val = df_leaf_smut.sample(n=6, random_state=101)
df_brown_spot_val = df_brown_spot.sample(n=6, random_state=101)
df_bacterial_leaf_blight_val = df_bacterial_leaf_blight.sample(n=6, random_state=101)


print(len(df_leaf_smut_val))
print(len(df_brown_spot_val))
print(len(df_bacterial_leaf_blight_val))
# Out:
# 6
# 6
# 6

# %%
df_leaf_smut
# Out:
#            image     target
# 0   DSC_0507.jpg  leaf_smut
# 1   DSC_0319.jpg  leaf_smut
# 2   DSC_0312.JPG  leaf_smut
# 3   DSC_0320.JPG  leaf_smut
# 4   DSC_0318.JPG  leaf_smut
# 5   DSC_0502.jpg  leaf_smut
# 6   DSC_0500.jpg  leaf_smut
# 7   DSC_0514.jpg  leaf_smut
# 8   DSC_0315.jpg  leaf_smut
# 9   DSC_0314.JPG  leaf_smut
# 10  DSC_0515.jpg  leaf_smut
# 11  DSC_0504.jpg  leaf_smut
# 12  DSC_0501.jpg  leaf_smut
# 13  DSC_0313.JPG  leaf_smut
# 14  DSC_0503.jpg  leaf_smut
# 15  DSC_0510.jpg  leaf_smut
# 16  DSC_0339.jpg  leaf_smut
# 17  DSC_0511.jpg  leaf_smut
# 18  DSC_0512.jpg  leaf_smut
# 19  DSC_0516.jpg  leaf_smut
# 20  DSC_0513.jpg  leaf_smut
# 21  DSC_0316.JPG  leaf_smut
# 22  DSC_0338.JPG  leaf_smut
# 23  DSC_0308.JPG  leaf_smut
# 24  DSC_0328.jpg  leaf_smut
# 25  DSC_0509.jpg  leaf_smut
# 26  DSC_0331.JPG  leaf_smut
# 27  DSC_0293.JPG  leaf_smut
# 28  DSC_0335.JPG  leaf_smut
# 29  DSC_0336.jpg  leaf_smut
# 30  DSC_0322.jpg  leaf_smut
# 31  DSC_0321.JPG  leaf_smut
# ...

# %%
df_leaf_smut_val
# Out:
#            image     target
# 18  DSC_0512.jpg  leaf_smut
# 16  DSC_0339.jpg  leaf_smut
# 36  DSC_0310.JPG  leaf_smut
# 25  DSC_0509.jpg  leaf_smut
# 26  DSC_0331.JPG  leaf_smut
# 30  DSC_0322.jpg  leaf_smut

# %%
# Create the train set for each class

# leaf_smut
# get a list of val images
val1_list = list(df_leaf_smut_val['image'])
# filter out the val images
df_leaf_smut_train = df_leaf_smut[~df_leaf_smut['image'].isin(val1_list)] # ~ means notin

# brown_spot
# get a list of val images
val2_list = list(df_brown_spot_val['image'])
# filter out the val images
df_brown_spot_train = df_brown_spot[~df_brown_spot['image'].isin(val2_list)] # ~ means notin

# bacterial_leaf_blight
# get a list of val images
val3_list = list(df_bacterial_leaf_blight_val['image'])
# filter out the val images
df_bacterial_leaf_blight_train = \
df_bacterial_leaf_blight[~df_bacterial_leaf_blight['image'].isin(val3_list)] # ~ means notin



print(len(df_leaf_smut_train))
print(len(df_brown_spot_train))
print(len(df_bacterial_leaf_blight_train))
# Out:
# 34
# 34
# 34

# %%
val1_list
# Out:
# ['DSC_0512.jpg',
#  'DSC_0339.jpg',
#  'DSC_0310.JPG',
#  'DSC_0509.jpg',
#  'DSC_0331.JPG',
#  'DSC_0322.jpg']

# %%
val2_list
# Out:
# ['DSC_0303.JPG',
#  'DSC_0105.jpg',
#  'DSC_0100.jpg',
#  'DSC_0305.JPG',
#  'DSC_0112.jpg',
#  'DSC_0302.JPG']

# %%
val3_list
# Out:
# ['DSC_0392.JPG',
#  'DSC_0702.jpg',
#  'DSC_0375.JPG',
#  'DSC_0396.JPG',
#  'DSC_0703.JPG',
#  'DSC_0382.JPG']

# %%
# Create df_data, df_train and df_val

df_data = pd.concat([df_leaf_smut, df_brown_spot, df_bacterial_leaf_blight], axis=0).reset_index(drop=True)

df_train = \
pd.concat([df_leaf_smut_train, df_brown_spot_train, df_bacterial_leaf_blight_train], axis=0).reset_index(drop=True)

df_val = \
pd.concat([df_leaf_smut_val, df_brown_spot_val, df_bacterial_leaf_blight_val], axis=0).reset_index(drop=True)

df_data = shuffle(df_data)
df_train = shuffle(df_train)
df_val = shuffle(df_val)

print(df_data.shape)
print(df_train.shape)
print(df_val.shape)
# Out:
# (120, 2)
# (102, 2)
# (18, 2)

# %%
df_train
# Out:
#             image                 target
# 101  DSC_0701.jpg  bacterial_leaf_blight
# 69   DSC_0401.JPG  bacterial_leaf_blight
# 62   DSC_0323.JPG             brown_spot
# 50   DSC_0333.JPG             brown_spot
# 73   DSC_0388.JPG  bacterial_leaf_blight
# ..            ...                    ...
# 36   DSC_0110.jpg             brown_spot
# 54   DSC_0106.jpg             brown_spot
# 89   DSC_0376.JPG  bacterial_leaf_blight
# 61   DSC_0329.jpg             brown_spot
# 8    DSC_0315.jpg              leaf_smut
#
# [102 rows x 2 columns]

# %%
df_val
# Out:
#            image                 target
# 16  DSC_0703.JPG  bacterial_leaf_blight
# 8   DSC_0100.jpg             brown_spot
# 6   DSC_0303.JPG             brown_spot
# 13  DSC_0702.jpg  bacterial_leaf_blight
# 2   DSC_0310.JPG              leaf_smut
# 9   DSC_0305.JPG             brown_spot
# 7   DSC_0105.jpg             brown_spot
# 11  DSC_0302.JPG             brown_spot
# 15  DSC_0396.JPG  bacterial_leaf_blight
# 12  DSC_0392.JPG  bacterial_leaf_blight
# 5   DSC_0322.jpg              leaf_smut
# 4   DSC_0331.JPG              leaf_smut
# 0   DSC_0512.jpg              leaf_smut
# 3   DSC_0509.jpg              leaf_smut
# 10  DSC_0112.jpg             brown_spot
# 17  DSC_0382.JPG  bacterial_leaf_blight
# 14  DSC_0375.JPG  bacterial_leaf_blight
# 1   DSC_0339.jpg              leaf_smut

# %% [markdown]
# ##- One-Hot Encoding

# %%
# Create the target as index values

# combine val, train and test
val_len = len(df_val)
train_len = len(df_train)
df_combined =  pd.concat(objs=[df_val, df_train], axis=0).reset_index(drop=True)

# create the dummy variables
df_combined = pd.get_dummies(df_combined, columns=['target'])

# separate the train and val sets
df_val = df_combined[:val_len]
df_train = df_combined[val_len:]


print(df_train.shape)
print(df_val.shape)
# Out:
# (102, 4)
# (18, 4)

# %%
df_train
# Out:
#             image  target_bacterial_leaf_blight  target_brown_spot  \
# 18   DSC_0701.jpg                             1                  0
# 19   DSC_0401.JPG                             1                  0
# 20   DSC_0323.JPG                             0                  1
# 21   DSC_0333.JPG                             0                  1
# 22   DSC_0388.JPG                             1                  0
# ..            ...                           ...                ...
# 115  DSC_0110.jpg                             0                  1
# 116  DSC_0106.jpg                             0                  1
# 117  DSC_0376.JPG                             1                  0
# 118  DSC_0329.jpg                             0                  1
# 119  DSC_0315.jpg                             0                  0
#
#      target_leaf_smut
# 18                  0
# 19                  0
# 20                  0
# 21                  0
# 22                  0
# ...

# %%
item = 'DSC_0702.jpg'
path = '/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight/' + item
image = plt.imread(path)
plt.imshow(image)
plt.xlabel('Bacterial leaf blight', fontsize=20)

plt.show()

# %%
item = 'DSC_0303.JPG'
path = '/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Brown spot-20200814T055208Z-001/Brown spot/' + item
image = plt.imread(path)
plt.imshow(image)
plt.xlabel('Brown spot', fontsize=20)
# Out:
# Text(0.5, 0, 'Brown spot')

# %%
import cv2
import os

def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        if img is not None:
            images.append(img)
    return images

# %%
images1=load_images_from_folder("/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight")
images2=load_images_from_folder("/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Brown spot-20200814T055208Z-001/Brown spot")
images3=load_images_from_folder("/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Leaf smut-20200814T055530Z-001/Leaf smut")

# %%
a=[images1,images2,images3]

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


for j in a:
  fig = plt.figure(figsize=(20,5))
  for i in range(40):
    ax = fig.add_subplot(4, 10, i + 1, xticks=[], yticks=[])
    ax.imshow(j[i])

# %%
df_combined
# Out:
#             image  target_bacterial_leaf_blight  target_brown_spot  \
# 0    DSC_0703.JPG                             1                  0
# 1    DSC_0100.jpg                             0                  1
# 2    DSC_0303.JPG                             0                  1
# 3    DSC_0702.jpg                             1                  0
# 4    DSC_0310.JPG                             0                  0
# ..            ...                           ...                ...
# 115  DSC_0110.jpg                             0                  1
# 116  DSC_0106.jpg                             0                  1
# 117  DSC_0376.JPG                             1                  0
# 118  DSC_0329.jpg                             0                  1
# 119  DSC_0315.jpg                             0                  0
#
#      target_leaf_smut
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   1
# ...

# %%
from sklearn.model_selection import train_test_split
x= df_combined['image']
y=df_combined.drop(['image'],axis=1)
(x_train, y_train), (x_test, y_test) = train_test_split(x,y,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-d4086de54999> in <module>
#       2 x= df_combined['image']
#       3 y=df_combined.drop(['image'],axis=1)
# ----> 4 (x_train, y_train), (x_test, y_test) = train_test_split(x,y,random_state=42)
#
# ValueError: too many values to unpack (expected 2)
