# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhi311509/Rice-Leaf-Detection/blob/main/CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
from skimage import io
import os, json, cv2, random

img_path = "/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight.jpg"
image = cv2.imread(img_path)
cv2_imshow(image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-19294d4aa604> in <module>
#       5 img_path = "/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight.jpg"
#       6 image = cv2.imread(img_path)
# ----> 7 cv2_imshow(image)
#
# /usr/local/lib/python3.8/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
img = cv2.imread('/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight.jpg')
img

# %%
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-d0027ef4e25a> in <module>
# ----> 1 cv2_imshow(img)
#
# /usr/local/lib/python3.8/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
import cv2

from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight.jpg')
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-cd82d2fcbfed> in <module>
#       1 img = cv2.imread('/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight.jpg')
# ----> 2 cv2_imshow(img)
#
# /usr/local/lib/python3.8/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
img_path= ('/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight.JPG')
img = cv2.imread(img_path)
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-353de1b7d47d> in <module>
#       1 img_path= ('/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight.JPG')
#       2 img = cv2.imread(img_path)
# ----> 3 cv2_imshow(img)
#
# /usr/local/lib/python3.8/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
import cv2
import os

def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        if img is not None:
            images.append(img)
    return images

# %%
load_images_from_folder("/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight")
# Out:
# [array([[[223, 229, 240],
#          [222, 228, 239],
#          [222, 228, 239],
#          ...,
#          [225, 230, 239],
#          [225, 230, 239],
#          [226, 231, 240]],
#
#         [[222, 228, 239],
#          [222, 228, 239],
#          [222, 228, 239],
#          ...,
#          [225, 230, 239],
#          [226, 231, 240],
#          [225, 230, 239]],
#
#         [[221, 227, 238],
#          [221, 227, 238],
#          [222, 228, 239],
#          ...,
#          [226, 231, 240],
#          [227, 232, 241],
#          [226, 231, 240]],
#
#         ...,
#
#         [[217, 227, 237],
#          [217, 227, 237],
#          [218, 228, 238],
#          ...,
#          [223, 226, 240],
#          [224, 227, 241],
#          [223, 226, 240]],
#
#         [[217, 227, 237],
#          [217, 227, 237],
#          [218, 228, 238],
#          ...,
#          [221, 225, 236],
#          [222, 225, 239],
#          [223, 226, 240]],
#
#         [[219, 228, 238],
#          [219, 228, 238],
#          [219, 228, 238],
#          ...,
#          [219, 226, 235],
#          [219, 225, 236],
#          [221, 227, 238]]], dtype=uint8), array([[[226, 232, 239],
#          [226, 232, 239],
#          [226, 232, 239],
#          ...,
#          [229, 235, 240],
#          [230, 236, 241],
#          [228, 234, 239]],
#
#         [[226, 232, 239],
#          [226, 232, 239],
#          [226, 232, 239],
#          ...,
#          [229, 235, 240],
#          [229, 235, 240],
#          [229, 235, 240]],
#
#         [[226, 232, 239],
#          [226, 232, 239],
#          [226, 232, 239],
#          ...,
#          [229, 235, 240],
#          [229, 235, 240],
#          [228, 234, 239]],
#
#         ...,
#
#         [[224, 229, 238],
#          [224, 229, 238],
#          [223, 230, 239],
#          ...,
#          [225, 230, 239],
#          [225, 230, 239],
#          [225, 230, 239]],
#
#         [[224, 229, 238],
#          [224, 229, 238],
#          [223, 230, 239],
#          ...,
#          [226, 231, 240],
#          [226, 231, 240],
#          [225, 230, 239]],
#
#         [[223, 230, 239],
#          [223, 230, 239],
#          [223, 230, 239],
#          ...,
#          [226, 232, 239],
#          [226, 232, 239],
#          [226, 229, 237]]], dtype=uint8), array([[[217, 223, 234],
#          [217, 223, 234],
#          [218, 224, 235],
#          ...,
#          [210, 213, 227],
#          [209, 212, 226],
#          [209, 212, 226]],
#
#         [[217, 223, 234],
#          [218, 224, 235],
#          [218, 224, 235],
#          ...,
#          [210, 213, 227],
#          [210, 213, 227],
#          [210, 213, 227]],
#
#         [[218, 224, 235],
#          [218, 224, 235],
#          [218, 224, 235],
#          ...,
#          [210, 213, 227],
#          [210, 213, 227],
#          [210, 213, 227]],
#
#         ...,
#
#         [[223, 225, 236],
#          [221, 223, 234],
#          [220, 222, 233],
#          ...,
#          [212, 214, 225],
#          [212, 214, 225],
#          [212, 214, 225]],
#
#         [[224, 226, 237],
#          [222, 224, 235],
#          [220, 222, 233],
#          ...,
#          [211, 213, 224],
#          [211, 213, 224],
#          [212, 214, 225]],
#
#         [[221, 225, 236],
#          [220, 224, 235],
#          [218, 222, 233],
#          ...,
#          [210, 214, 225],
#          [210, 214, 225],
#          [210, 214, 225]]], dtype=uint8), array([[[218, 222, 233],
#          [218, 222, 233],
#          [218, 222, 233],
#          ...,
#          [220, 222, 232],
#          [222, 222, 234],
#          [226, 224, 236]],
#
#         [[219, 220, 234],
#          [221, 222, 236],
#          [221, 222, 236],
#          ...,
#          [219, 221, 232],
#          [219, 221, 232],
#          [220, 220, 232]],
#
#         [[220, 221, 235],
#          [220, 221, 235],
#          [221, 222, 236],
#          ...,
#          [221, 223, 234],
#          [221, 223, 234],
#          [221, 223, 234]],
#
#         ...,
#
#         [[216, 219, 233],
#          [218, 221, 235],
#          [217, 220, 234],
#          ...,
#          [216, 219, 234],
#          [216, 219, 234],
#          [217, 220, 235]],
#
#         [[217, 220, 234],
#          [216, 219, 233],
#          [216, 219, 233],
#          ...,
#          [216, 219, 234],
#          [217, 219, 237],
#          [217, 219, 237]],
#
#         [[213, 216, 230],
#          [214, 217, 231],
#          [215, 218, 232],
#          ...,
#          [217, 220, 235],
#          [217, 219, 237],
#          [218, 220, 238]]], dtype=uint8), array([[[208, 214, 227],
#          [209, 215, 228],
#          [209, 215, 228],
#          ...,
#          [210, 215, 230],
#          [210, 215, 230],
#          [210, 215, 230]],
#
#         [[208, 214, 227],
#          [209, 215, 228],
#          [209, 215, 228],
#          ...,
#          [210, 215, 230],
#          [210, 215, 230],
#          [209, 214, 229]],
#
#         [[208, 214, 227],
#          [209, 215, 228],
#          [209, 215, 228],
#          ...,
#          [210, 215, 230],
#          [210, 215, 230],
#          [209, 214, 229]],
#
#         ...,
#
#         [[208, 216, 229],
#          [208, 216, 229],
#          [208, 216, 229],
#          ...,
#          [211, 217, 230],
#          [211, 217, 230],
#          [213, 216, 230]],
#
#         [[208, 216, 229],
#          [208, 216, 229],
#          [208, 216, 229],
#          ...,
#          [210, 216, 229],
#          [210, 216, 229],
#          [213, 216, 230]],
#
#         [[211, 217, 230],
#          [211, 217, 230],
#          [210, 216, 229],
#          ...,
#          [210, 216, 229],
#          [211, 217, 230],
#          [211, 217, 230]]], dtype=uint8), array([[[209, 214, 229],
#          [209, 214, 229],
#          [210, 215, 230],
#          ...,
#          [211, 215, 226],
#          [211, 215, 226],
#          [212, 216, 227]],
#
#         [[209, 214, 229],
#          [209, 214, 229],
#          [210, 215, 230],
#          ...,
#          [211, 215, 226],
#          [210, 214, 225],
#          [212, 216, 227]],
#
#         [[209, 214, 229],
#          [209, 214, 229],
#          [209, 214, 229],
#          ...,
#          [210, 216, 227],
#          [209, 215, 226],
#          [210, 216, 227]],
#
#         ...,
#
#         [[212, 215, 230],
#          [211, 214, 229],
#          [211, 214, 229],
#          ...,
#          [207, 213, 226],
#          [207, 213, 226],
#          [208, 214, 225]],
#
#         [[213, 216, 231],
#          [212, 215, 230],
#          [211, 214, 229],
#          ...,
#          [208, 214, 227],
#          [208, 214, 227],
#          [209, 215, 226]],
#
#         [[211, 215, 233],
#          [211, 215, 233],
#          [210, 214, 232],
#          ...,
#          [210, 214, 225],
#          [209, 213, 224],
#          [206, 212, 223]]], dtype=uint8), array([[[226, 231, 240],
#          [226, 231, 240],
#          [226, 231, 240],
#          ...,
#          [219, 222, 236],
#          [220, 223, 237],
#          [221, 224, 238]],
#
#         [[226, 231, 240],
#          [226, 231, 240],
#          [226, 231, 240],
#          ...,
#          [219, 222, 236],
#          [220, 223, 237],
#          [221, 224, 238]],
#
#         [[224, 231, 240],
#          [224, 231, 240],
#          [226, 231, 240],
#          ...,
#          [220, 223, 237],
#          [221, 224, 238],
#          [220, 223, 237]],
#
#         ...,
#
#         [[217, 229, 241],
#          [217, 229, 241],
#          [217, 229, 239],
#          ...,
#          [214, 222, 239],
#          [214, 222, 239],
#          [216, 224, 241]],
#
#         [[217, 229, 241],
#          [217, 229, 241],
#          [217, 229, 239],
#          ...,
#          [215, 223, 240],
#          [214, 222, 239],
#          [216, 224, 241]],
#
#         [[218, 228, 238],
#          [219, 229, 239],
#          [220, 230, 240],
#          ...,
#          [214, 222, 239],
#          [216, 224, 241],
#          [216, 224, 241]]], dtype=uint8), array([[[225, 231, 238],
#          [225, 231, 238],
#          [227, 230, 238],
#          ...,
#          [223, 231, 238],
#          [223, 231, 238],
#          [224, 232, 239]],
#
#         [[225, 231, 238],
#          [225, 231, 238],
#          [228, 231, 239],
#          ...,
#          [223, 231, 238],
#          [223, 231, 238],
#          [223, 231, 238]],
#
#         [[225, 231, 238],
#          [226, 232, 239],
#          [229, 232, 240],
#          ...,
#          [223, 230, 239],
#          [223, 230, 239],
#          [222, 229, 238]],
#
#         ...,
#
#         [[222, 228, 239],
#          [222, 228, 239],
#          [222, 228, 239],
#          ...,
#          [223, 227, 238],
#          [222, 226, 237],
#          [224, 226, 237]],
#
#         [[223, 229, 240],
#          [223, 229, 240],
#          [222, 228, 239],
#          ...,
#          [223, 227, 238],
#          [223, 227, 238],
#          [225, 227, 238]],
#
#         [[222, 229, 238],
#          [223, 230, 239],
#          [223, 230, 239],
#          ...,
#          [225, 227, 238],
#          [225, 227, 238],
#          [224, 225, 239]]], dtype=uint8), array([[[226, 232, 239],
#          [226, 232, 239],
#          [226, 232, 239],
#          ...,
#          [224, 229, 238],
#          [224, 229, 238],
#          [226, 231, 240]],
#
#         [[226, 232, 239],
#          [226, 232, 239],
#          [226, 232, 239],
#          ...,
#          [224, 229, 238],
#          [224, 229, 238],
#          [226, 231, 240]],
#
#         [[225, 231, 238],
#          [226, 232, 239],
#          [225, 231, 238],
#          ...,
#          [225, 230, 239],
#          [225, 230, 239],
#          [224, 229, 238]],
#
#         ...,
#
#         [[221, 230, 239],
#          [221, 230, 239],
#          [221, 230, 239],
#          ...,
#          [220, 226, 237],
#          [220, 226, 237],
#          [221, 227, 238]],
#
#         [[221, 230, 239],
#          [221, 230, 239],
#          [221, 230, 239],
#          ...,
#          [220, 226, 237],
#          [220, 226, 237],
#          [221, 227, 238]],
#
#         [[221, 228, 237],
#          [223, 230, 239],
#          [223, 230, 239],
#          ...,
#          [218, 227, 237],
#          [219, 228, 238],
#          [222, 228, 239]]], dtype=uint8), array([[[213, 222, 231],
#          [214, 223, 232],
#          [215, 224, 234],
#          ...,
#          [219, 228, 238],
#          [219, 228, 238],
#          [219, 228, 238]],
#
#         [[214, 223, 232],
#          [214, 223, 232],
#          [215, 224, 234],
#          ...,
#          [219, 228, 238],
#          [219, 228, 238],
#          [219, 228, 238]],
#
#         [[216, 225, 235],
#          [216, 225, 235],
#          [217, 225, 238],
#          ...,
#          [219, 228, 238],
#          [219, 228, 238],
#          [218, 227, 237]],
#
#         ...,
#
#         [[219, 223, 234],
#          [220, 224, 235],
#          [221, 225, 236],
#          ...,
#          [218, 226, 239],
#          [218, 226, 239],
#          [218, 227, 237]],
#
#         [[219, 223, 234],
#          [220, 224, 235],
#          [221, 225, 236],
#          ...,
#          [219, 227, 240],
#          [219, 227, 240],
#          [218, 227, 237]],
#
#         [[219, 223, 234],
#          [220, 224, 235],
#          [221, 225, 236],
#          ...,
#          [219, 228, 238],
#          [220, 229, 239],
#          [220, 229, 239]]], dtype=uint8), array([[[231, 235, 240],
#          [232, 236, 241],
#          [232, 236, 241],
#          ...,
#          [225, 230, 239],
#          [225, 230, 239],
#          [222, 227, 236]],
#
#         [[229, 233, 238],
#          [230, 234, 239],
#          [230, 234, 239],
#          ...,
#          [225, 230, 239],
#          [224, 229, 238],
#          [223, 228, 237]],
#
#         [[230, 234, 239],
#          [230, 234, 239],
#          [230, 234, 239],
#          ...,
#          [226, 231, 240],
#          [225, 230, 239],
#          [224, 229, 238]],
#
#         ...,
#
#         [[232, 233, 243],
#          [232, 233, 243],
#          [232, 233, 243],
#          ...,
#          [226, 230, 241],
#          [227, 231, 242],
#          [227, 230, 244]],
#
#         [[232, 233, 243],
#          [232, 233, 243],
#          [232, 233, 243],
#          ...,
#          [226, 230, 241],
#          [227, 231, 242],
#          [226, 229, 243]],
#
#         [[231, 234, 242],
#          [231, 234, 242],
#          [231, 234, 242],
#          ...,
#          [225, 230, 239],
#          [225, 230, 239],
#          [222, 228, 239]]], dtype=uint8), array([[[234, 237, 245],
#          [235, 238, 246],
#          [235, 238, 246],
#          ...,
#          [159, 147, 147],
#          [159, 147, 147],
#          [157, 145, 145]],
#
#         [[233, 236, 244],
#          [234, 237, 245],
#          [234, 237, 245],
#          ...,
#          [157, 145, 145],
#          [157, 145, 145],
#          [156, 144, 144]],
#
#         [[233, 236, 244],
#          [233, 236, 244],
#          [233, 236, 244],
#          ...,
#          [156, 146, 146],
#          [155, 145, 145],
#          [155, 145, 145]],
#
#         ...,
#
#         [[234, 238, 243],
#          [234, 238, 243],
#          [234, 238, 243],
#          ...,
#          [236, 238, 246],
#          [236, 238, 246],
#          [236, 238, 246]],
#
#         [[234, 238, 243],
#          [234, 238, 243],
#          [234, 238, 243],
#          ...,
#          [236, 238, 246],
#          [236, 238, 246],
#          [236, 238, 246]],
#
#         [[233, 236, 244],
#          [234, 237, 245],
#          [235, 238, 246],
#          ...,
#          [235, 238, 246],
#          [235, 238, 246],
#          [235, 238, 246]]], dtype=uint8), array([[[220, 225, 240],
#          [220, 225, 240],
#          [220, 225, 240],
#          ...,
#          [229, 232, 240],
#          [229, 232, 240],
#          [229, 232, 240]],
#
#         [[220, 225, 240],
#          [220, 225, 240],
#          [220, 225, 240],
#          ...,
#          [230, 233, 241],
#          [230, 233, 241],
#          [226, 229, 237]],
#
#         [[219, 224, 239],
#          [219, 224, 239],
#          [219, 225, 238],
#          ...,
#          [228, 234, 241],
#          [228, 234, 241],
#          [227, 233, 240]],
#
#         ...,
#
#         [[218, 226, 239],
#          [218, 226, 239],
#          [220, 226, 239],
#          ...,
#          [226, 228, 238],
#          [226, 228, 238],
#          [227, 229, 239]],
#
#         [[221, 227, 240],
#          [221, 227, 240],
#          [221, 227, 240],
#          ...,
#          [226, 228, 238],
#          [224, 229, 238],
#          [226, 228, 238]],
#
#         [[223, 227, 238],
#          [223, 227, 238],
#          [222, 226, 237],
#          ...,
#          [223, 228, 237],
#          [221, 228, 237],
#          [223, 227, 238]]], dtype=uint8), array([[[226, 231, 240],
#          [227, 232, 241],
#          [227, 232, 241],
#          ...,
#          [217, 223, 234],
#          [216, 222, 233],
#          [217, 223, 234]],
#
#         [[227, 232, 241],
#          [227, 232, 241],
#          [227, 232, 241],
#          ...,
#          [217, 223, 234],
#          [216, 222, 233],
#          [215, 221, 232]],
#
#         [[227, 232, 241],
#          [227, 232, 241],
#          [226, 231, 240],
#          ...,
#          [217, 223, 234],
#          [217, 223, 234],
#          [215, 221, 232]],
#
#         ...,
#
#         [[229, 232, 240],
#          [229, 232, 240],
#          [229, 232, 240],
#          ...,
#          [218, 224, 235],
#          [219, 225, 236],
#          [218, 224, 235]],
#
#         [[228, 231, 239],
#          [229, 232, 240],
#          [230, 233, 241],
#          ...,
#          [218, 224, 235],
#          [219, 225, 236],
#          [220, 226, 237]],
#
#         [[229, 232, 240],
#          [230, 233, 241],
#          [228, 231, 239],
#          ...,
#          [219, 226, 235],
#          [219, 226, 235],
#          [219, 226, 235]]], dtype=uint8), array([[[234, 236, 244],
#          [235, 237, 245],
#          [235, 237, 245],
#          ...,
#          [220, 230, 240],
#          [221, 231, 241],
#          [222, 232, 242]],
#
#         [[234, 236, 244],
#          [235, 237, 245],
#          [235, 237, 245],
#          ...,
#          [219, 229, 239],
#          [220, 230, 240],
#          [222, 232, 242]],
#
#         [[235, 237, 245],
#          [235, 237, 245],
#          [235, 237, 245],
#          ...,
#          [220, 230, 240],
#          [220, 230, 240],
#          [222, 232, 242]],
#
#         ...,
#
#         [[231, 234, 242],
#          [231, 234, 242],
#          [231, 234, 242],
#          ...,
#          [230, 233, 241],
#          [230, 233, 241],
#          [231, 234, 242]],
#
#         [[232, 235, 243],
#          [232, 235, 243],
#          [231, 234, 242],
#          ...,
#          [229, 232, 240],
#          [230, 233, 241],
#          [231, 234, 242]],
#
#         [[231, 234, 242],
#          [231, 234, 242],
#          [231, 234, 242],
#          ...,
#          [230, 233, 241],
#          [230, 233, 241],
#          [230, 234, 239]]], dtype=uint8), array([[[215, 219, 237],
#          [215, 219, 237],
#          [215, 219, 237],
#          ...,
#          [203, 211, 228],
#          [203, 211, 228],
#          [204, 211, 228]],
#
#         [[215, 219, 237],
#          [215, 219, 237],
#          [214, 218, 236],
#          ...,
#          [203, 211, 228],
#          [202, 210, 227],
#          [204, 211, 228]],
#
#         [[214, 218, 236],
#          [214, 218, 236],
#          [214, 218, 236],
#          ...,
#          [203, 210, 227],
#          [203, 210, 227],
#          [203, 210, 227]],
#
#         ...,
#
#         [[215, 220, 235],
#          [215, 220, 235],
#          [214, 219, 234],
#          ...,
#          [203, 210, 229],
#          [203, 210, 229],
#          [205, 212, 232]],
#
#         [[214, 218, 236],
#          [214, 219, 234],
#          [213, 217, 235],
#          ...,
#          [204, 211, 230],
#          [205, 212, 231],
#          [203, 210, 230]],
#
#         [[211, 215, 234],
#          [213, 217, 235],
#          [216, 217, 237],
#          ...,
#          [204, 211, 230],
#          [203, 210, 229],
#          [201, 211, 229]]], dtype=uint8), array([[[230, 232, 240],
#          [231, 233, 241],
#          [231, 233, 241],
#          ...,
#          [229, 231, 241],
#          [230, 232, 242],
#          [230, 232, 242]],
#
#         [[232, 234, 242],
#          [232, 234, 242],
#          [232, 234, 242],
#          ...,
#          [230, 232, 242],
#          [230, 232, 242],
#          [230, 232, 242]],
#
#         [[233, 235, 243],
#          [232, 234, 242],
#          [232, 234, 242],
#          ...,
#          [230, 232, 242],
#          [230, 232, 242],
#          [230, 232, 242]],
#
#         ...,
#
#         [[232, 234, 242],
#          [232, 234, 242],
#          [232, 234, 242],
#          ...,
#          [224, 231, 240],
#          [224, 231, 240],
#          [223, 230, 239]],
#
#         [[232, 234, 242],
#          [232, 234, 242],
#          [232, 234, 242],
#          ...,
#          [224, 231, 240],
#          [224, 231, 240],
#          [223, 230, 239]],
#
#         [[232, 235, 240],
#          [232, 235, 240],
#          [231, 234, 239],
#          ...,
#          [225, 230, 239],
#          [225, 230, 239],
#          [225, 229, 240]]], dtype=uint8), array([[[220, 226, 237],
#          [221, 227, 238],
#          [221, 227, 238],
#          ...,
#          [217, 220, 235],
#          [218, 221, 236],
#          [218, 221, 235]],
#
#         [[220, 226, 237],
#          [220, 226, 237],
#          [220, 226, 237],
#          ...,
#          [217, 220, 235],
#          [219, 222, 237],
#          [218, 221, 235]],
#
#         [[220, 226, 237],
#          [220, 226, 237],
#          [219, 225, 236],
#          ...,
#          [218, 221, 236],
#          [219, 222, 237],
#          [219, 222, 237]],
#
#         ...,
#
#         [[217, 223, 234],
#          [218, 224, 235],
#          [219, 225, 236],
#          ...,
#          [216, 222, 235],
#          [216, 222, 235],
#          [216, 222, 235]],
#
#         [[217, 223, 234],
#          [218, 224, 235],
#          [219, 225, 236],
#          ...,
#          [216, 222, 235],
#          [217, 223, 236],
#          [217, 223, 236]],
#
#         [[217, 223, 236],
#          [218, 224, 237],
#          [219, 225, 238],
#          ...,
#          [216, 221, 236],
#          [215, 220, 235],
#          [215, 220, 235]]], dtype=uint8), array([[[220, 224, 235],
#          [220, 224, 235],
#          [220, 224, 235],
#          ...,
#          [220, 222, 233],
#          [220, 222, 233],
#          [221, 223, 234]],
#
#         [[220, 224, 235],
#          [220, 224, 235],
#          [219, 223, 234],
#          ...,
#          [223, 225, 236],
#          [223, 225, 236],
#          [223, 225, 236]],
#
#         [[220, 224, 235],
#          [219, 223, 234],
#          [219, 223, 234],
#          ...,
#          [224, 226, 237],
#          [224, 226, 237],
#          [224, 226, 237]],
#
#         ...,
#
#         [[214, 221, 236],
#          [214, 221, 236],
#          [215, 222, 237],
#          ...,
#          [216, 222, 235],
#          [216, 222, 235],
#          [216, 222, 235]],
#
#         [[214, 221, 236],
#          [215, 222, 237],
#          [215, 222, 237],
#          ...,
#          [215, 221, 234],
#          [215, 221, 234],
#          [215, 221, 234]],
#
#         [[215, 223, 236],
#          [214, 222, 235],
#          [213, 221, 234],
#          ...,
#          [215, 220, 235],
#          [214, 219, 234],
#          [215, 220, 235]]], dtype=uint8), array([[[212, 216, 227],
#          [212, 216, 227],
#          [212, 215, 229],
#          ...,
#          [219, 225, 238],
#          [220, 226, 239],
#          [219, 225, 238]],
#
#         [[211, 215, 226],
#          [211, 215, 226],
#          [211, 214, 228],
#          ...,
#          [218, 224, 237],
#          [218, 224, 237],
#          [217, 223, 236]],
#
#         [[211, 215, 226],
#          [211, 215, 226],
#          [211, 214, 228],
#          ...,
#          [216, 221, 236],
#          [215, 220, 235],
#          [218, 223, 238]],
#
#         ...,
#
#         [[212, 221, 231],
#          [213, 222, 232],
#          [213, 222, 232],
#          ...,
#          [221, 223, 234],
#          [221, 223, 234],
#          [221, 222, 236]],
#
#         [[212, 221, 231],
#          [212, 221, 231],
#          [212, 221, 231],
#          ...,
#          [220, 222, 233],
#          [220, 222, 233],
#          [221, 222, 236]],
#
#         [[213, 222, 232],
#          [213, 222, 232],
#          [213, 222, 232],
#          ...,
#          [218, 219, 233],
#          [219, 220, 234],
#          [218, 221, 235]]], dtype=uint8), array([[[212, 217, 232],
#          [211, 216, 231],
#          [211, 216, 231],
#          ...,
#          [220, 224, 235],
#          [221, 225, 236],
#          [219, 225, 236]],
#
#         [[211, 216, 231],
#          [211, 216, 231],
#          [211, 216, 231],
#          ...,
#          [220, 224, 235],
#          [220, 224, 235],
#          [220, 226, 237]],
#
#         [[210, 215, 230],
#          [211, 216, 231],
#          [212, 217, 232],
#          ...,
#          [220, 224, 235],
#          [220, 224, 235],
#          [220, 226, 237]],
#
#         ...,
#
#         [[213, 221, 238],
#          [213, 221, 238],
#          [213, 221, 238],
#          ...,
#          [218, 221, 235],
#          [218, 221, 235],
#          [217, 222, 237]],
#
#         [[213, 221, 238],
#          [213, 221, 238],
#          [213, 221, 238],
#          ...,
#          [218, 221, 235],
#          [219, 222, 236],
#          [217, 222, 237]],
#
#         [[213, 220, 237],
#          [213, 220, 237],
#          [214, 221, 238],
#          ...,
#          [217, 220, 235],
#          [218, 221, 236],
#          [217, 220, 235]]], dtype=uint8), array([[[219, 228, 238],
#          [220, 229, 239],
#          [220, 229, 239],
#          ...,
#          [212, 220, 237],
#          [212, 220, 237],
#          [211, 221, 239]],
#
#         [[218, 227, 237],
#          [219, 228, 238],
#          [219, 228, 238],
#          ...,
#          [210, 218, 235],
#          [210, 218, 235],
#          [209, 219, 237]],
#
#         [[218, 227, 237],
#          [218, 227, 237],
#          [219, 228, 238],
#          ...,
#          [209, 217, 234],
#          [210, 218, 235],
#          [211, 218, 237]],
#
#         ...,
#
#         [[218, 228, 238],
#          [218, 228, 238],
#          [219, 229, 239],
#          ...,
#          [216, 225, 239],
#          [216, 225, 239],
#          [217, 226, 240]],
#
#         [[218, 228, 238],
#          [218, 228, 238],
#          [218, 228, 238],
#          ...,
#          [216, 225, 239],
#          [216, 225, 239],
#          [217, 226, 240]],
#
#         [[218, 227, 237],
#          [219, 228, 238],
#          [219, 228, 238],
#          ...,
#          [217, 226, 239],
#          [217, 226, 239],
#          [218, 226, 239]]], dtype=uint8), array([[[215, 223, 240],
#          [215, 223, 240],
#          [214, 222, 239],
#          ...,
#          [224, 227, 241],
#          [224, 227, 241],
#          [225, 227, 238]],
#
#         [[215, 223, 240],
#          [215, 223, 240],
#          [215, 223, 240],
#          ...,
#          [224, 227, 241],
#          [223, 226, 240],
#          [223, 225, 236]],
#
#         [[216, 224, 241],
#          [217, 225, 242],
#          [218, 226, 243],
#          ...,
#          [223, 227, 238],
#          [222, 226, 237],
#          [222, 224, 235]],
#
#         ...,
#
#         [[137, 125, 121],
#          [136, 124, 120],
#          [134, 122, 118],
#          ...,
#          [218, 225, 240],
#          [219, 226, 241],
#          [219, 227, 240]],
#
#         [[137, 125, 121],
#          [135, 123, 119],
#          [134, 122, 118],
#          ...,
#          [219, 226, 241],
#          [219, 226, 241],
#          [219, 227, 240]],
#
#         [[135, 123, 119],
#          [137, 125, 121],
#          [137, 125, 119],
#          ...,
#          [219, 227, 240],
#          [218, 226, 239],
#          [219, 227, 240]]], dtype=uint8), array([[[218, 226, 239],
#          [218, 226, 239],
#          [218, 226, 239],
#          ...,
#          [220, 223, 238],
#          [219, 222, 237],
#          [218, 221, 236]],
#
#         [[218, 226, 239],
#          [218, 226, 239],
#          [218, 226, 239],
#          ...,
#          [219, 222, 237],
#          [219, 222, 237],
#          [219, 222, 237]],
#
#         [[218, 226, 239],
#          [218, 226, 239],
#          [218, 226, 239],
#          ...,
#          [219, 222, 237],
#          [218, 221, 236],
#          [219, 221, 239]],
#
#         ...,
#
#         [[216, 224, 241],
#          [216, 224, 241],
#          [216, 224, 241],
#          ...,
#          [219, 228, 238],
#          [219, 228, 238],
#          [222, 228, 239]],
#
#         [[216, 224, 241],
#          [216, 224, 241],
#          [216, 224, 241],
#          ...,
#          [219, 228, 238],
#          [220, 229, 239],
#          [222, 228, 239]],
#
#         [[215, 224, 238],
#          [215, 224, 238],
#          [215, 224, 238],
#          ...,
#          [219, 228, 237],
#          [218, 227, 236],
#          [222, 229, 238]]], dtype=uint8), array([[[222, 228, 239],
#          [223, 229, 240],
#          [223, 229, 240],
#          ...,
#          [217, 226, 236],
#          [218, 227, 237],
#          [219, 227, 240]],
#
#         [[222, 228, 239],
#          [223, 229, 240],
#          [223, 229, 240],
#          ...,
#          [218, 227, 237],
#          [219, 228, 238],
#          [219, 227, 240]],
#
#         [[222, 228, 239],
#          [222, 228, 239],
#          [222, 228, 239],
#          ...,
#          [219, 228, 238],
#          [219, 228, 238],
#          [219, 227, 240]],
#
#         ...,
#
#         [[218, 228, 238],
#          [218, 228, 238],
#          [218, 228, 238],
#          ...,
#          [222, 231, 241],
#          [222, 231, 241],
#          [223, 232, 242]],
#
#         [[218, 228, 238],
#          [218, 228, 238],
#          [218, 228, 238],
#          ...,
#          [222, 231, 241],
#          [222, 231, 241],
#          [223, 232, 242]],
#
#         [[218, 229, 237],
#          [218, 229, 237],
#          [218, 229, 237],
#          ...,
#          [221, 230, 240],
#          [222, 231, 241],
#          [223, 232, 241]]], dtype=uint8), array([[[216, 223, 238],
#          [216, 223, 238],
#          [216, 223, 238],
#          ...,
#          [211, 218, 235],
#          [212, 219, 236],
#          [210, 217, 234]],
#
#         [[216, 223, 238],
#          [216, 223, 238],
#          [216, 223, 238],
#          ...,
#          [211, 218, 235],
#          [211, 218, 235],
#          [212, 219, 236]],
#
#         [[216, 223, 238],
#          [216, 223, 238],
#          [215, 222, 237],
#          ...,
#          [210, 217, 234],
#          [211, 218, 235],
#          [212, 219, 236]],
#
#         ...,
#
#         [[218, 227, 237],
#          [218, 227, 237],
#          [218, 227, 237],
#          ...,
#          [215, 219, 237],
#          [215, 219, 237],
#          [215, 219, 237]],
#
#         [[219, 228, 238],
#          [219, 228, 238],
#          [219, 228, 238],
#          ...,
#          [214, 218, 236],
#          [214, 218, 236],
#          [215, 219, 237]],
#
#         [[221, 227, 238],
#          [220, 226, 237],
#          [221, 227, 238],
#          ...,
#          [213, 220, 237],
#          [213, 220, 237],
#          [216, 220, 238]]], dtype=uint8), array([[[223, 227, 238],
#          [222, 226, 237],
#          [220, 226, 237],
#          ...,
#          [212, 217, 232],
#          [213, 218, 233],
#          [212, 217, 232]],
#
#         [[223, 227, 238],
#          [222, 226, 237],
#          [220, 226, 237],
#          ...,
#          [212, 217, 232],
#          [213, 218, 233],
#          [212, 217, 232]],
#
#         [[222, 226, 237],
#          [222, 226, 237],
#          [220, 226, 237],
#          ...,
#          [212, 217, 232],
#          [213, 218, 233],
#          [212, 217, 232]],
#
#         ...,
#
#         [[216, 222, 241],
#          [217, 223, 242],
#          [217, 224, 241],
#          ...,
#          [209, 216, 235],
#          [210, 217, 236],
#          [209, 216, 235]],
#
#         [[217, 224, 241],
#          [217, 224, 241],
#          [217, 224, 241],
#          ...,
#          [209, 216, 235],
#          [210, 217, 236],
#          [209, 216, 235]],
#
#         [[215, 224, 238],
#          [215, 224, 238],
#          [217, 224, 239],
#          ...,
#          [211, 218, 235],
#          [211, 218, 235],
#          [211, 218, 235]]], dtype=uint8), array([[[226, 231, 240],
#          [225, 230, 239],
#          [225, 230, 239],
#          ...,
#          [222, 228, 239],
#          [222, 228, 239],
#          [222, 228, 239]],
#
#         [[225, 230, 239],
#          [224, 229, 238],
#          [225, 230, 239],
#          ...,
#          [221, 227, 238],
#          [222, 228, 239],
#          [222, 228, 239]],
#
#         [[224, 229, 238],
#          [224, 229, 238],
#          [224, 229, 238],
#          ...,
#          [222, 228, 239],
#          [223, 229, 240],
#          [223, 229, 240]],
#
#         ...,
#
#         [[228, 230, 240],
#          [228, 230, 240],
#          [225, 230, 239],
#          ...,
#          [221, 227, 240],
#          [222, 228, 241],
#          [223, 229, 242]],
#
#         [[228, 230, 240],
#          [227, 229, 239],
#          [224, 229, 238],
#          ...,
#          [222, 228, 241],
#          [224, 230, 241],
#          [223, 229, 242]],
#
#         [[222, 228, 235],
#          [223, 229, 236],
#          [224, 230, 237],
#          ...,
#          [220, 226, 237],
#          [220, 227, 236],
#          [219, 225, 236]]], dtype=uint8), array([[[226, 231, 240],
#          [226, 231, 240],
#          [226, 231, 240],
#          ...,
#          [213, 220, 237],
#          [215, 222, 239],
#          [214, 221, 238]],
#
#         [[226, 231, 240],
#          [226, 231, 240],
#          [226, 231, 240],
#          ...,
#          [213, 220, 237],
#          [215, 222, 239],
#          [213, 220, 237]],
#
#         [[226, 232, 239],
#          [226, 232, 239],
#          [226, 231, 240],
#          ...,
#          [212, 219, 236],
#          [213, 220, 237],
#          [213, 220, 237]],
#
#         ...,
#
#         [[218, 227, 236],
#          [218, 227, 236],
#          [220, 226, 237],
#          ...,
#          [216, 223, 238],
#          [216, 223, 238],
#          [217, 224, 239]],
#
#         [[217, 226, 235],
#          [217, 226, 235],
#          [219, 225, 236],
#          ...,
#          [215, 222, 237],
#          [216, 223, 238],
#          [214, 221, 236]],
#
#         [[217, 226, 235],
#          [216, 225, 234],
#          [216, 225, 235],
#          ...,
#          [214, 221, 236],
#          [215, 222, 237],
#          [215, 222, 237]]], dtype=uint8), array([[[211, 218, 235],
#          [212, 219, 236],
#          [212, 219, 236],
#          ...,
#          [201, 208, 225],
#          [201, 208, 225],
#          [201, 208, 223]],
#
#         [[212, 219, 236],
#          [212, 219, 236],
#          [212, 219, 236],
#          ...,
#          [200, 207, 224],
#          [201, 208, 225],
#          [198, 205, 220]],
#
#         [[212, 219, 236],
#          [211, 218, 235],
#          [211, 218, 235],
#          ...,
#          [200, 207, 222],
#          [200, 207, 222],
#          [199, 206, 221]],
#
#         ...,
#
#         [[212, 220, 237],
#          [212, 220, 237],
#          [213, 220, 237],
#          ...,
#          [207, 213, 226],
#          [208, 214, 227],
#          [207, 212, 227]],
#
#         [[212, 220, 237],
#          [212, 220, 237],
#          [213, 220, 237],
#          ...,
#          [207, 213, 226],
#          [207, 213, 226],
#          [207, 212, 227]],
#
#         [[212, 220, 237],
#          [213, 221, 238],
#          [213, 221, 238],
#          ...,
#          [205, 210, 225],
#          [206, 211, 226],
#          [207, 213, 226]]], dtype=uint8), array([[[219, 225, 236],
#          [220, 226, 237],
#          [221, 227, 238],
#          ...,
#          [209, 213, 232],
#          [208, 212, 231],
#          [208, 212, 231]],
#
#         [[220, 226, 237],
#          [220, 226, 237],
#          [220, 226, 237],
#          ...,
#          [207, 211, 230],
#          [207, 211, 230],
#          [207, 211, 230]],
#
#         [[220, 226, 237],
#          [220, 226, 237],
#          [219, 225, 236],
#          ...,
#          [207, 211, 229],
#          [208, 212, 230],
#          [207, 211, 229]],
#
#         ...,
#
#         [[219, 225, 238],
#          [219, 225, 238],
#          [216, 224, 237],
#          ...,
#          [210, 216, 227],
#          [210, 216, 227],
#          [213, 217, 228]],
#
#         [[219, 225, 238],
#          [219, 225, 238],
#          [217, 225, 238],
#          ...,
#          [209, 215, 226],
#          [209, 215, 226],
#          [213, 217, 228]],
#
#         [[218, 227, 237],
#          [217, 226, 236],
#          [217, 226, 236],
#          ...,
#          [214, 218, 229],
#          [213, 217, 228],
#          [213, 217, 228]]], dtype=uint8), array([[[221, 224, 238],
#          [222, 225, 239],
#          [222, 225, 239],
#          ...,
#          [228, 231, 239],
#          [228, 231, 239],
#          [228, 231, 239]],
#
#         [[221, 224, 238],
#          [222, 225, 239],
#          [222, 225, 239],
#          ...,
#          [228, 231, 239],
#          [228, 231, 239],
#          [228, 231, 239]],
#
#         [[221, 224, 238],
#          [222, 225, 239],
#          [222, 225, 239],
#          ...,
#          [228, 231, 239],
#          [228, 231, 239],
#          [228, 231, 239]],
#
#         ...,
#
#         [[216, 223, 238],
#          [216, 223, 238],
#          [216, 223, 238],
#          ...,
#          [220, 229, 239],
#          [220, 229, 239],
#          [222, 231, 241]],
#
#         [[216, 223, 238],
#          [216, 223, 238],
#          [216, 223, 238],
#          ...,
#          [220, 229, 239],
#          [220, 229, 239],
#          [221, 230, 240]],
#
#         [[216, 224, 237],
#          [216, 224, 237],
#          [216, 224, 237],
#          ...,
#          [219, 228, 238],
#          [220, 229, 239],
#          [220, 229, 239]]], dtype=uint8), array([[[218, 227, 236],
#          [219, 228, 237],
#          [222, 229, 238],
#          ...,
#          [221, 227, 238],
#          [221, 227, 238],
#          [218, 224, 235]],
#
#         [[219, 228, 237],
#          [220, 229, 238],
#          [223, 230, 239],
#          ...,
#          [220, 226, 237],
#          [220, 226, 237],
#          [219, 225, 236]],
#
#         [[220, 229, 238],
#          [221, 230, 239],
#          [223, 230, 239],
#          ...,
#          [220, 226, 237],
#          [219, 225, 236],
#          [220, 226, 237]],
#
#         ...,
#
#         [[219, 228, 238],
#          [219, 228, 238],
#          [219, 228, 238],
#          ...,
#          [218, 225, 240],
#          [218, 225, 240],
#          [217, 224, 239]],
#
#         [[219, 228, 238],
#          [219, 228, 238],
#          [218, 227, 237],
#          ...,
#          [218, 225, 240],
#          [218, 225, 240],
#          [217, 224, 239]],
#
#         [[220, 229, 239],
#          [220, 229, 239],
#          [220, 229, 239],
#          ...,
#          [219, 227, 240],
#          [218, 226, 239],
#          [217, 225, 238]]], dtype=uint8), array([[[221, 228, 237],
#          [222, 229, 238],
#          [222, 229, 238],
#          ...,
#          [214, 219, 234],
#          [215, 220, 235],
#          [215, 220, 235]],
#
#         [[222, 229, 238],
#          [222, 229, 238],
#          [222, 229, 238],
#          ...,
#          [216, 221, 236],
#          [216, 221, 236],
#          [217, 222, 237]],
#
#         [[222, 229, 238],
#          [223, 230, 239],
#          [223, 230, 239],
#          ...,
#          [215, 220, 235],
#          [214, 219, 234],
#          [216, 221, 236]],
#
#         ...,
#
#         [[221, 227, 240],
#          [222, 228, 241],
#          [222, 228, 241],
#          ...,
#          [212, 220, 237],
#          [212, 220, 237],
#          [210, 218, 235]],
#
#         [[221, 227, 240],
#          [223, 229, 242],
#          [223, 229, 242],
#          ...,
#          [212, 220, 237],
#          [211, 219, 236],
#          [213, 221, 238]],
#
#         [[223, 229, 240],
#          [221, 227, 238],
#          [220, 226, 237],
#          ...,
#          [209, 219, 236],
#          [208, 218, 235],
#          [209, 219, 236]]], dtype=uint8), array([[[221, 224, 238],
#          [221, 224, 238],
#          [220, 223, 237],
#          ...,
#          [225, 229, 240],
#          [226, 230, 241],
#          [224, 228, 239]],
#
#         [[221, 224, 238],
#          [220, 223, 237],
#          [220, 223, 237],
#          ...,
#          [225, 229, 240],
#          [225, 229, 240],
#          [226, 230, 241]],
#
#         [[220, 223, 237],
#          [220, 223, 237],
#          [220, 223, 237],
#          ...,
#          [225, 229, 240],
#          [225, 229, 240],
#          [227, 231, 242]],
#
#         ...,
#
#         [[218, 224, 237],
#          [218, 224, 237],
#          [219, 225, 238],
#          ...,
#          [228, 231, 239],
#          [227, 230, 238],
#          [228, 231, 239]],
#
#         [[218, 224, 237],
#          [218, 224, 237],
#          [219, 225, 238],
#          ...,
#          [228, 231, 239],
#          [227, 230, 238],
#          [228, 231, 239]],
#
#         [[221, 224, 238],
#          [221, 224, 238],
#          [221, 224, 238],
#          ...,
#          [226, 232, 239],
#          [225, 231, 238],
#          [228, 231, 239]]], dtype=uint8), array([[[229, 231, 241],
#          [230, 232, 242],
#          [230, 232, 242],
#          ...,
#          [222, 226, 237],
#          [222, 226, 237],
#          [222, 226, 237]],
#
#         [[229, 231, 241],
#          [230, 232, 242],
#          [230, 232, 242],
#          ...,
#          [222, 226, 237],
#          [222, 226, 237],
#          [222, 226, 237]],
#
#         [[229, 231, 241],
#          [230, 232, 242],
#          [230, 232, 242],
#          ...,
#          [222, 226, 237],
#          [222, 226, 237],
#          [222, 226, 237]],
#
#         ...,
#
#         [[222, 228, 239],
#          [221, 227, 238],
#          [221, 227, 238],
#          ...,
#          [225, 231, 238],
#          [225, 231, 238],
#          [225, 231, 238]],
#
#         [[221, 227, 238],
#          [221, 227, 238],
#          [221, 227, 238],
#          ...,
#          [226, 232, 239],
#          [225, 231, 238],
#          [225, 231, 238]],
#
#         [[225, 230, 239],
#          [224, 229, 238],
#          [223, 228, 237],
#          ...,
#          [223, 230, 239],
#          [223, 230, 239],
#          [225, 231, 238]]], dtype=uint8), array([[[214, 221, 238],
#          [215, 222, 239],
#          [215, 222, 239],
#          ...,
#          [216, 223, 238],
#          [216, 223, 238],
#          [217, 224, 239]],
#
#         [[214, 221, 238],
#          [215, 222, 239],
#          [215, 222, 239],
#          ...,
#          [216, 223, 238],
#          [216, 223, 238],
#          [217, 224, 239]],
#
#         [[214, 221, 238],
#          [215, 222, 239],
#          [215, 222, 239],
#          ...,
#          [216, 223, 238],
#          [216, 223, 238],
#          [216, 223, 238]],
#
#         ...,
#
#         [[217, 223, 236],
#          [217, 223, 236],
#          [217, 223, 236],
#          ...,
#          [215, 220, 235],
#          [214, 219, 234],
#          [213, 218, 233]],
#
#         [[217, 223, 236],
#          [217, 223, 236],
#          [217, 223, 236],
#          ...,
#          [215, 220, 235],
#          [214, 219, 234],
#          [213, 218, 233]],
#
#         [[217, 222, 237],
#          [217, 222, 237],
#          [217, 222, 237],
#          ...,
#          [215, 220, 235],
#          [214, 219, 234],
#          [215, 220, 235]]], dtype=uint8), array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]]], dtype=uint8), array([[[104, 133, 147],
#          [105, 134, 148],
#          [108, 135, 149],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[108, 137, 151],
#          [108, 137, 151],
#          [112, 139, 153],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[110, 139, 154],
#          [110, 139, 154],
#          [114, 140, 156],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]]], dtype=uint8), array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [ 70, 121,  83],
#          [ 56, 115,  71],
#          [ 51, 110,  66]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [ 70, 121,  83],
#          [ 56, 114,  73],
#          [ 51, 110,  66]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [ 70, 121,  83],
#          [ 55, 113,  72],
#          [ 51, 110,  66]]], dtype=uint8)]

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(40):
    ax = fig.add_subplot(4, 10, i + 1, xticks=[], yticks=[])
    ax.imshow(images[i])

# %%
x= c[:]
y= c[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-f5492978ce5c> in <module>
# ----> 1 x= c[:]
#       2 y= c[:]
#
# TypeError: 'AxesImage' object is not subscriptable

# %%
(x_train, y_train), (x_test, y_test) = train_test_split(x, y, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-40fb299c4b8e> in <module>
# ----> 1 (x_train, y_train), (x_test, y_test) = train_test_split(x, y, random_state=1)
#
# ValueError: too many values to unpack (expected 2)

# %%
from sklearn.model_selection import train_test_split
# create dataset
X, y = c()
# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-dbf10f5df3ca> in <module>
#       1 from sklearn.model_selection import train_test_split
#       2 # create dataset
# ----> 3 X, y = c()
#       4 # split into train test sets
#       5 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
#
# TypeError: 'AxesImage' object is not callable

# %%
# split into input and output elements
data = images.values
X, y = data[:, :-1], data[:, -1]
print(X.shape, y.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-5cf27d260a0b> in <module>
#       1 # split into input and output elements
# ----> 2 data = images.values
#       3 X, y = data[:, :-1], data[:, -1]
#       4 print(X.shape, y.shape)
#
# AttributeError: 'list' object has no attribute 'values'

# %%
# !pip install split-folders

import splitfolders
splitfolders.ratio('Bacterial leaf blight', output="output", seed=1337, ratio=(.8, 0.0,0.2))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: split-folders in /usr/local/lib/python3.8/dist-packages (0.5.1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-c557dad683e1> in <module>
#       2
#       3 import splitfolders
# ----> 4 splitfolders.ratio('Bacterial leaf blight', output="output", seed=1337, ratio=(.8, 0.0,0.2))
#
# /usr/local/lib/python3.8/dist-packages/splitfolders/split.py in ratio(input, output, seed, ratio, group_prefix, move)
#      79         raise ValueError("`ratio` should")
#      80
# ---> 81     check_input_format(input)
#      82
#      83     if use_tqdm:
#
# /usr/local/lib/python3.8/dist-packages/splitfolders/split.py in check_input_format(input)
#      54         if not p_input.is_absolute():
#      55             err_msg += f' Your relative path cannot be found from the current working directory "{Path.cwd()}".'
# ---> 56         raise ValueError(err_msg)
#      57
#      58     if not p_input.is_dir():
#
# ValueError: The provided input folder "Bacterial leaf blight" does not exists. Your relative path cannot be found from the current working directory "/content".

# %%
from __future__ import absolute_import, print_function,division, unicode_literals

import os.path
import glob
import shutil

import tensorflow as tf
assert tf.__version__.startswith('2')

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D,Flatten,MaxPooling2D,Dropout,Dense,Activation
from keras import regularizers
import keras

import numpy as np
import matplotlib.pyplot as plt
import pathlib

# %%
import pathlib
data_dir ="/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data"
data_dir = pathlib.Path(data_dir)

CLASS_NAMES = np.array(['Bacterial leaf Blight','Brown spot','Leaf smut'])

print('Class Names: ', CLASS_NAMES)
# Out:
# Class Names:  ['Bacterial leaf Blight' 'Brown spot' 'Leaf smut']

# %%
BATCH_SIZE = 8
IMG_HEIGHT = 224
IMG_WIDTH = 224

# %%
train_path = "/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data"
test_path = "/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data"

# %%
image_train_gen = ImageDataGenerator(rescale=1./255,
                                     zoom_range=0.50,
                                     rotation_range=45,
                                     horizontal_flip=True,
                                     width_shift_range=0.15,
                                     height_shift_range=0.15)

train_data_gen = image_train_gen.flow_from_directory(train_path,
                                                     shuffle=True,
                                                     batch_size=BATCH_SIZE,
                                                     target_size=(IMG_HEIGHT,IMG_WIDTH),
                                                     class_mode='sparse')

img_val_gen = ImageDataGenerator(rescale=1./255)
val_data_gen = img_val_gen.flow_from_directory(test_path,
                                               batch_size=BATCH_SIZE,
                                               target_size=(IMG_HEIGHT,IMG_WIDTH),
                                               class_mode='sparse')
# Out:
# Found 119 images belonging to 3 classes.
# Found 119 images belonging to 3 classes.

# %%
def plotImages(image_arr):
    fig,axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img,ax in zip(image_arr,axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
img_array = [train_data_gen[0][0][0] for i in range(119)]
plotImages(img_array)

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import os

import cv2




from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

from sklearn.metrics import confusion_matrix
import itertools
from sklearn.metrics import classification_report

import shutil

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224
IMAGE_CHANNELS = 3

# %%
os.listdir('/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data')
# Out:
# ['Bacterial leaf blight-20200814T055237Z-001',
#  'Brown spot-20200814T055208Z-001',
#  'Leaf smut-20200814T055530Z-001']

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
leaf_smut_list = \
os.listdir('/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Leaf smut-20200814T055530Z-001/Leaf smut')
brown_spot_list = \
os.listdir('/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Brown spot-20200814T055208Z-001/Brown spot')
bacterial_leaf_blight_list = \
os.listdir('/content/drive/MyDrive/Internships/PRCP-1001-RiceLeaf/Data/Bacterial leaf blight-20200814T055237Z-001/Bacterial leaf blight')

print(len(leaf_smut_list))
print(len(brown_spot_list))
print(len(bacterial_leaf_blight_list))
# Out:
# 39
# 40
# 40

# %%
df_leaf_smut = pd.DataFrame(leaf_smut_list, columns=['image'])
df_leaf_smut['target'] = 'leaf_smut'

df_brown_spot = pd.DataFrame(brown_spot_list, columns=['image'])
df_brown_spot['target'] = 'brown_spot'

df_bacterial_leaf_blight = pd.DataFrame(bacterial_leaf_blight_list, columns=['image'])
df_bacterial_leaf_blight['target'] = 'bacterial_leaf_blight'


# Create a val set for each class

# Sample 5 validation images from each class
df_leaf_smut_val = df_leaf_smut.sample(n=6, random_state=101)
df_brown_spot_val = df_brown_spot.sample(n=6, random_state=101)
df_bacterial_leaf_blight_val = df_bacterial_leaf_blight.sample(n=6, random_state=101)


print(len(df_leaf_smut_val))
print(len(df_brown_spot_val))
print(len(df_bacterial_leaf_blight_val))
# Out:
# 6
# 6
# 6

# %%
df_leaf_smut
# Out:
#            image     target
# 0   DSC_0313.JPG  leaf_smut
# 1   DSC_0312.JPG  leaf_smut
# 2   DSC_0310.JPG  leaf_smut
# 3   DSC_0309.JPG  leaf_smut
# 4   DSC_0308.JPG  leaf_smut
# 5   DSC_0293.JPG  leaf_smut
# 6   DSC_0314.JPG  leaf_smut
# 7   DSC_0320.JPG  leaf_smut
# 8   DSC_0319.jpg  leaf_smut
# 9   DSC_0318.JPG  leaf_smut
# 10  DSC_0316.JPG  leaf_smut
# 11  DSC_0317.JPG  leaf_smut
# 12  DSC_0315.jpg  leaf_smut
# 13  DSC_0335.JPG  leaf_smut
# 14  DSC_0331.JPG  leaf_smut
# 15  DSC_0330.jpg  leaf_smut
# 16  DSC_0328.jpg  leaf_smut
# 17  DSC_0327.JPG  leaf_smut
# 18  DSC_0322.jpg  leaf_smut
# 19  DSC_0321.JPG  leaf_smut
# 20  DSC_0513.jpg  leaf_smut
# 21  DSC_0512.jpg  leaf_smut
# 22  DSC_0511.jpg  leaf_smut
# 23  DSC_0510.jpg  leaf_smut
# 24  DSC_0509.jpg  leaf_smut
# 25  DSC_0507.jpg  leaf_smut
# 26  DSC_0506.jpg  leaf_smut
# 27  DSC_0505.jpg  leaf_smut
# 28  DSC_0503.jpg  leaf_smut
# 29  DSC_0504.jpg  leaf_smut
# 30  DSC_0501.jpg  leaf_smut
# 31  DSC_0500.jpg  leaf_smut
# 32  DSC_0502.jpg  leaf_smut
# 33  DSC_0339.jpg  leaf_smut
# 34  DSC_0338.JPG  leaf_smut
# 35  DSC_0336.jpg  leaf_smut
# 36  DSC_0516.jpg  leaf_smut
# 37  DSC_0515.jpg  leaf_smut
# 38  DSC_0514.jpg  leaf_smut

# %%
df_leaf_smut_val
# Out:
#            image     target
# 27  DSC_0505.jpg  leaf_smut
# 20  DSC_0513.jpg  leaf_smut
# 35  DSC_0336.jpg  leaf_smut
# 24  DSC_0509.jpg  leaf_smut
# 38  DSC_0514.jpg  leaf_smut
# 29  DSC_0504.jpg  leaf_smut

# %%
val1_list
# Out:
# ['DSC_0505.jpg',
#  'DSC_0513.jpg',
#  'DSC_0336.jpg',
#  'DSC_0509.jpg',
#  'DSC_0514.jpg',
#  'DSC_0504.jpg']

# %%
val2_list
# Out:
# ['DSC_0104.jpg',
#  'DSC_0106.jpg',
#  'DSC_0324.JPG',
#  'DSC_0303.JPG',
#  'DSC_0302.JPG',
#  'DSC_0296.jpg']

# %%
# Create the train set for each class

# leaf_smut
# get a list of val images
val1_list = list(df_leaf_smut_val['image'])
# filter out the val images
df_leaf_smut_train = df_leaf_smut[~df_leaf_smut['image'].isin(val1_list)] # ~ means notin

# brown_spot
# get a list of val images
val2_list = list(df_brown_spot_val['image'])
# filter out the val images
df_brown_spot_train = df_brown_spot[~df_brown_spot['image'].isin(val2_list)] # ~ means notin

# bacterial_leaf_blight
# get a list of val images
val3_list = list(df_bacterial_leaf_blight_val['image'])
# filter out the val images
df_bacterial_leaf_blight_train = \
df_bacterial_leaf_blight[~df_bacterial_leaf_blight['image'].isin(val3_list)] # ~ means notin



print(len(df_leaf_smut_train))
print(len(df_brown_spot_train))
print(len(df_bacterial_leaf_blight_train))
# Out:
# 33
# 34
# 34

# %%
# Create df_data, df_train and df_val

df_data = pd.concat([df_leaf_smut, df_brown_spot, df_bacterial_leaf_blight], axis=0).reset_index(drop=True)

df_train = \
pd.concat([df_leaf_smut_train, df_brown_spot_train, df_bacterial_leaf_blight_train], axis=0).reset_index(drop=True)

df_val = \
pd.concat([df_leaf_smut_val, df_brown_spot_val, df_bacterial_leaf_blight_val], axis=0).reset_index(drop=True)

df_data = shuffle(df_data)
df_train = shuffle(df_train)
df_val = shuffle(df_val)

print(df_data.shape)
print(df_train.shape)
print(df_val.shape)
# Out:
# (119, 2)
# (101, 2)
# (18, 2)

# %%
df_train
# Out:
#            image                 target
# 64  DSC_0323.JPG             brown_spot
# 70  DSC_0367.JPG  bacterial_leaf_blight
# 83  DSC_0377.JPG  bacterial_leaf_blight
# 37  DSC_0115.jpg             brown_spot
# 54  DSC_0305.JPG             brown_spot
# ..           ...                    ...
# 23  DSC_0507.jpg              leaf_smut
# 87  DSC_0405.JPG  bacterial_leaf_blight
# 41  DSC_0119.jpg             brown_spot
# 50  DSC_0101.jpg             brown_spot
# 53  DSC_0306.JPG             brown_spot
#
# [101 rows x 2 columns]

# %%
df_val
# Out:
#            image                 target
# 8   DSC_0324.JPG             brown_spot
# 12  DSC_0378.JPG  bacterial_leaf_blight
# 1   DSC_0513.jpg              leaf_smut
# 11  DSC_0296.jpg             brown_spot
# 17  DSC_0397.JPG  bacterial_leaf_blight
# 2   DSC_0336.jpg              leaf_smut
# 14  DSC_0703.JPG  bacterial_leaf_blight
# 16  DSC_0401.JPG  bacterial_leaf_blight
# 0   DSC_0505.jpg              leaf_smut
# 5   DSC_0504.jpg              leaf_smut
# 4   DSC_0514.jpg              leaf_smut
# 3   DSC_0509.jpg              leaf_smut
# 9   DSC_0303.JPG             brown_spot
# 6   DSC_0104.jpg             brown_spot
# 15  DSC_0402.JPG  bacterial_leaf_blight
# 7   DSC_0106.jpg             brown_spot
# 13  DSC_0379.JPG  bacterial_leaf_blight
# 10  DSC_0302.JPG             brown_spot
